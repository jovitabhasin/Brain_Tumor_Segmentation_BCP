# %%
# Importing the most important library numpy
# Numpy is preffered over python lists since most of its implementations are faster (the functions are tied closer with hardware)
import numpy as np

# %% [markdown]
# ### Run the following to grasp the basics of numpy

# %%
# 1D array
arr1 = np.array([1, 2, 3])
print("1D Array:", arr1)

# 2D array
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D Array:\n", arr2)

# Array of zeros
zeros = np.zeros((2, 3))
print("Zeros Array:\n", zeros)

# Array of ones
ones = np.ones((3, 2))
print("Ones Array:\n", ones)

# Array with a range of values
range_arr = np.arange(0, 10, 2)
print("Range Array:", range_arr)

# Array with equally spaced values
linspace_arr = np.linspace(0, 1, 5)
print("Linspace Array:", linspace_arr)

# Random array
random_arr = np.random.rand(3, 3)  # Uniform distribution
print("Random Array:\n", random_arr)
# Out:
# 1D Array: [1 2 3]
# 2D Array:
#  [[1 2 3]
#  [4 5 6]]
# Zeros Array:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Ones Array:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# Range Array: [0 2 4 6 8]
# Linspace Array: [0.   0.25 0.5  0.75 1.  ]
# Random Array:
#  [[0.29827236 0.06566621 0.18452085]
#  [0.47973468 0.53609366 0.88555323]
#  [0.27229152 0.68877038 0.73520876]]

# %%
# In a numpy array, all the elements must be homogenous (of the same data type)
arr = np.array([[1, 2, 3], [4, 5, 6]])

print("Shape:", arr.shape)  # Dimensions
print("Size:", arr.size)  # Total number of elements
print("Data Type:", arr.dtype)  # Type of elements
print("Number of Dimensions:", arr.ndim)  # Number of dimensions
# Out:
# Shape: (2, 3)
# Size: 6
# Data Type: int64
# Number of Dimensions: 2

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

# Accessing elements
print("Element at [0, 1]:", arr[0, 1])  # Row 0, Column 1

# Slicing
print("First row:", arr[0, :])  # All columns of the first row
print("First column:", arr[:, 0])  # All rows of the first column
print("Subarray:\n", arr[0:2, 1:3])  # Rows 0-1 and Columns 1-2
# Out:
# Element at [0, 1]: 2
# First row: [1 2 3]
# First column: [1 4]
# Subarray:
#  [[2 3]
#  [5 6]]

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# Element-wise operations
print("Addition:", arr1 + arr2)
print("Multiplication:", arr1 * arr2)
print("Division:", arr2 / arr1)

# Broadcasting
scalar = 2
print("Multiply by scalar:", arr1 * scalar)

# Mathematical functions
print("Square root:", np.sqrt(arr1))
print("Exponential:", np.exp(arr1))
# Out:
# Addition: [5 7 9]
# Multiplication: [ 4 10 18]
# Division: [4.  2.5 2. ]
# Multiply by scalar: [2 4 6]
# Square root: [1.         1.41421356 1.73205081]
# Exponential: [ 2.71828183  7.3890561  20.08553692]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

# Reshape
reshaped = arr.reshape((3, 2))
print("Reshaped Array:\n", reshaped)

# Transpose
transposed = arr.T
print("Transposed Array:\n", transposed)
# Out:
# Reshaped Array:
#  [[1 2]
#  [3 4]
#  [5 6]]
# Transposed Array:
#  [[1 4]
#  [2 5]
#  [3 6]]

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# Stacking
stacked = np.vstack((arr1, arr2))  # Vertical stack
print("Stacked Vertically:\n", stacked)

hstacked = np.hstack((arr1, arr2))  # Horizontal stack
print("Stacked Horizontally:", hstacked)

# Splitting
split = np.split(arr2, 3)  # Split into 3 parts
print("Split Array:", split)
# Out:
# Stacked Vertically:
#  [[1 2 3]
#  [4 5 6]]
# Stacked Horizontally: [1 2 3 4 5 6]
# Split Array: [array([4]), array([5]), array([6])]

# %%
arr = np.array([1, 2, 3, 4, 5, 6])

# Boolean indexing
even = arr[arr % 2 == 0]
print("Even Numbers:", even)
# Masking is a common technique used
print("Masking:", arr % 2 == 0)

# Filtering
filtered = arr[arr > 3]
print("Numbers greater than 3:", filtered)
# Out:
# Even Numbers: [2 4 6]
# Masking: [False  True False  True False  True]
# Numbers greater than 3: [4 5 6]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])

print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Sum: 21
# Mean: 3.5
# Maximum: 6
# Minimum: 1
# Standard Deviation: 1.707825127659933

# %% [markdown]
# ### Some assignment problems

# %%
# Assignment 1
'''
Create an array of 18 random elements of shape (3, 6) and add the array [0, 0, 2, 4, 5, 3] to each row.
Then reshape it to a (9, 2) array and take its transpose.
Find the locations where all elements are greater than the mean of the array and print it
'''
# Out:
# '\nCreate an array of 18 random elements of shape (3, 6) and add the array [0, 0, 2, 4, 5, 3] to each row.\nThen reshape it to a (9, 2) array and take its transpose. \nFind the locations where all elements are greater than the mean of the array and print it\n'

# %%
# TODO

# %%
# Assignment 2
'''
Create an array of length 20 that models a poisson distribution and center it around the mean and normalise it by dividing it by the standard deviation
(Centering around some value "a" is subtracting "a" from each element and normalising is to divide it by some factor)
'''
# Out:
# '\nCreate an array of length 20 that models a poisson distribution and center it around the mean and normalise it by dividing it by the standard deviation\n(Centering around some value "a" is subtracting "a" from each element and normalising is to divide it by some factor)\n'

# %%
# TODO
# Hint use np.random.poisson

# %%
random_array = np.random.rand(3, 6)
print("Original Random Array (3, 6):\n", random_array)

add_array = np.array([0, 0, 2, 4, 5, 3])
print("\nArray to add to each row:\n", add_array)

modified_array = random_array + add_array
print("\nModified Array (after adding to each row):\n", modified_array)

reshaped_array = modified_array.reshape((9, 2))
print("\nReshaped Array (9, 2):\n", reshaped_array)

final_array = reshaped_array.T
print("\nFinal Transposed Array:\n", final_array)
# Out:
# Original Random Array (3, 6):
#  [[0.37692288 0.38845757 0.54125332 0.15990578 0.72163615 0.65516572]
#  [0.95312517 0.45497431 0.51944297 0.83828278 0.07721429 0.29858051]
#  [0.91182808 0.58131288 0.2328293  0.78052982 0.43206141 0.51527656]]
#
# Array to add to each row:
#  [0 0 2 4 5 3]
#
# Modified Array (after adding to each row):
#  [[0.37692288 0.38845757 2.54125332 4.15990578 5.72163615 3.65516572]
#  [0.95312517 0.45497431 2.51944297 4.83828278 5.07721429 3.29858051]
#  [0.91182808 0.58131288 2.2328293  4.78052982 5.43206141 3.51527656]]
#
# Reshaped Array (9, 2):
#  [[0.37692288 0.38845757]
#  [2.54125332 4.15990578]
#  [5.72163615 3.65516572]
#  [0.95312517 0.45497431]
#  [2.51944297 4.83828278]
#  [5.07721429 3.29858051]
#  [0.91182808 0.58131288]
#  [2.2328293  4.78052982]
#  [5.43206141 3.51527656]]
#
# Final Transposed Array:
#  [[0.37692288 2.54125332 5.72163615 0.95312517 2.51944297 5.07721429
#   0.91182808 2.2328293  5.43206141]
#  [0.38845757 4.15990578 3.65516572 0.45497431 4.83828278 3.29858051
#   0.58131288 4.78052982 3.51527656]]

# %%
mean_final_array = np.mean(final_array)
print("\nMean of the Final Transposed Array:", mean_final_array)
locations_greater_than_mean = np.argwhere(final_array > mean_final_array)
print("\nLocations where elements are greater than the mean:\n", locations_greater_than_mean)
# Out:
# Mean of the Final Transposed Array: 2.807812415834042
#
# Locations where elements are greater than the mean:
#  [[0 2]
#  [0 5]
#  [0 8]
#  [1 1]
#  [1 2]
#  [1 4]
#  [1 5]
#  [1 7]
#  [1 8]]

# %%
poisson_array = np.random.poisson(lam=5, size=20)
print("Original Poisson Array:\n", poisson_array)

mean_poisson = np.mean(poisson_array)
print("\nMean of Poisson Array:", mean_poisson)

std_poisson = np.std(poisson_array)
print("Standard Deviation of Poisson Array:", std_poisson)

centered_array = poisson_array - mean_poisson
print("\nCentered Poisson Array:\n", centered_array)

normalized_array = centered_array / std_poisson
print("\nNormalized Poisson Array:\n", normalized_array)
# Out:
# Original Poisson Array:
#  [8 2 7 6 4 4 6 2 6 8 7 0 5 7 3 4 7 7 3 5]
#
# Mean of Poisson Array: 5.05
# Standard Deviation of Poisson Array: 2.1788758569500923
#
# Centered Poisson Array:
#  [ 2.95 -3.05  1.95  0.95 -1.05 -1.05  0.95 -3.05  0.95  2.95  1.95 -5.05
#  -0.05  1.95 -2.05 -1.05  1.95  1.95 -2.05 -0.05]
#
# Normalized Poisson Array:
#  [ 1.35390917 -1.39980439  0.89495691  0.43600465 -0.48189987 -0.48189987
#   0.43600465 -1.39980439  0.43600465  1.35390917  0.89495691 -2.31770892
#  -0.02294761  0.89495691 -0.94085213 -0.48189987  0.89495691  0.89495691
#  -0.94085213 -0.02294761]
